# %%
from stanfordcorenlp import StanfordCoreNLP
import pandas as pd
import json
import os
import re

# %%
nlp = StanfordCoreNLP(r'C:\Users\user\stanfordcorenlp', lang='zh')

# %%
data = pd.read_csv('movie_review.csv')

# %%
data
# Out:
#        fold_id cv_tag  html_id  sent_id  \
# 0            0  cv000    29590        0
# 1            0  cv000    29590        1
# 2            0  cv000    29590        2
# 3            0  cv000    29590        3
# 4            0  cv000    29590        4
# 5            0  cv000    29590        5
# 6            0  cv000    29590        6
# 7            0  cv000    29590        7
# 8            0  cv000    29590        8
# 9            0  cv000    29590        9
# 10           0  cv000    29590       10
# 11           0  cv000    29590       11
# 12           0  cv000    29590       12
# 13           0  cv000    29590       13
# 14           0  cv000    29590       14
# 15           0  cv000    29590       15
# 16           0  cv000    29590       16
# 17           0  cv000    29590       17
# 18           0  cv000    29590       18
# 19           0  cv000    29590       19
# 20           0  cv000    29590       20
# 21           0  cv000    29590       21
# 22           0  cv000    29590       22
# 23           0  cv000    29590       23
# 24           0  cv000    29590       24
# 25           0  cv001    18431        0
# 26           0  cv001    18431        1
# 27           0  cv001    18431        2
# 28           0  cv001    18431        3
# 29           0  cv001    18431        4
# ...        ...    ...      ...      ...
# 64690        9  cv998    15691       20
# 64691        9  cv998    15691       21
# 64692        9  cv998    15691       22
# 64693        9  cv998    15691       23
# 64694        9  cv998    15691       24
# 64695        9  cv999    14636        0
# 64696        9  cv999    14636        1
# 64697        9  cv999    14636        2
# 64698        9  cv999    14636        3
# 64699        9  cv999    14636        4
# 64700        9  cv999    14636        5
# 64701        9  cv999    14636        6
# 64702        9  cv999    14636        7
# 64703        9  cv999    14636        8
# 64704        9  cv999    14636        9
# 64705        9  cv999    14636       10
# 64706        9  cv999    14636       11
# 64707        9  cv999    14636       12
# 64708        9  cv999    14636       13
# 64709        9  cv999    14636       14
# 64710        9  cv999    14636       15
# 64711        9  cv999    14636       16
# 64712        9  cv999    14636       17
# 64713        9  cv999    14636       18
# 64714        9  cv999    14636       19
# 64715        9  cv999    14636       20
# 64716        9  cv999    14636       21
# 64717        9  cv999    14636       22
# 64718        9  cv999    14636       23
# 64719        9  cv999    14636       24
#
#                                                     text  tag
# 0      films adapted from comic books have had plenty...  pos
# 1      for starters , it was created by alan moore ( ...  pos
# 2      to say moore and campbell thoroughly researche...  pos
# 3      the book ( or " graphic novel , " if you will ...  pos
# 4      in other words , don't dismiss this film becau...  pos
# 5      if you can get past the whole comic book thing...  pos
# 6      getting the hughes brothers to direct this see...  pos
# 7      the ghetto in question is , of course , whitec...  pos
# 8      it's a filthy , sooty place where the whores (...  pos
# 9      when the first stiff turns up , copper peter g...  pos
# 10     abberline , a widower , has prophetic dreams h...  pos
# 11     upon arriving in whitechapel , he befriends an...  pos
# 12     i don't think anyone needs to be briefed on ja...  pos
# 13     in the comic , they don't bother cloaking the ...  pos
# 14     it's funny to watch the locals blindly point t...  pos
# 15     and from hell's ending had me whistling the st...  pos
# 16     don't worry - it'll all make sense when you se...  pos
# 17     now onto from hell's appearance : it's certain...  pos
# 18     the print i saw wasn't completely finished ( b...  pos
# 19     oscar winner martin childs' ( shakespeare in l...  pos
# 20     even the acting in from hell is solid , with t...  pos
# 21     ians holm ( joe gould's secret ) and richardso...  pos
# 22     i cringed the first time she opened her mouth ...  pos
# 23                    the film , however , is all good .  pos
# 24     2 : 00 - r for strong violence/gore , sexualit...  pos
# 25     every now and then a movie comes along from a ...  pos
# 26     mtv films' _election , a high school comedy st...  pos
# 27     did anybody know this film existed a week befo...  pos
# 28                      the plot is deceptively simple .  pos
# 29     george washington carver high school is having...  pos
# ...                                                  ...  ...
# 64690  and sheryl lee ( faring much better as laura p...  neg
# 64691  there is not an ounce of intelligence , or exc...  neg
# 64692  he has said that he turned down directing , " ...  neg
# 64693  and yet , when asked about a " vampires " sequ...  neg
# 64694  i think that's a definite sign that carpenter ...  neg
# 64695  two party guys bob their heads to haddaway's d...  neg
# 64696  while getting themselves into trouble in night...  neg
# 64697  it's barely enough to sustain a three-minute _...  neg
# 64698              emphasis on the word " presumably . "  neg
# 64699  _a_night_at_the_roxbury_ takes an already-thin...  neg
# 64700  the first five minutes or so of _roxbury_ play...  neg
# 64701                            with " what is love ? "  neg
# 64702  blaring on the soundtrack , the brotherly duo ...  neg
# 64703  there is one crucial difference , however--the...  neg
# 64704  that little fact has been used as justificatio...  neg
# 64705  the doors opened by director john fortenberry ...  neg
# 64706  there is no story per se , only a loosely stru...  neg
# 64707  the brothers literally run into ( or , rather ...  neg
# 64708  there , they meet a hotshot club owner ( chazz...  neg
# 64709  meanwhile , the bros' overbearing father ( dan...  neg
# 64710  when doug refuses and the dimwitted steve obey...  neg
# 64711  the narrative messiness of _roxbury_ would hav...  neg
# 64712  the assembled press audience mostly sat stonil...  neg
# 64713  alas , the joke--a rather lazy takeoff on _jer...  neg
# 64714  granted , a lot of people _have_ seen _jerry_m...  neg
# 64715  that lack of inspiration can be traced back to...  neg
# 64716  like too many of the skits on the current inca...  neg
# 64717  after watching one of the " roxbury " skits on...  neg
# 64718   bump unsuspecting women , and . . . that's all .  neg
# 64719  after watching _a_night_at_the_roxbury_ , you'...  neg
#
# [64720 rows x 6 columns]

# %%
#Split them into train/test set, randomly with the test size 0.33 
# from sklearn.model_selection import train_test_split
# x_train, x_test = train_test_split(data.Reviews, test_size = 0.999, shuffle = True)
x_train = data['text'][:300]

# %%
print(len(x_train))
# x_train.reset_index(drop = True, inplace = True)
# Out:
# 300

# %%
x_train
# Out:
# 0      films adapted from comic books have had plenty...
# 1      for starters , it was created by alan moore ( ...
# 2      to say moore and campbell thoroughly researche...
# 3      the book ( or " graphic novel , " if you will ...
# 4      in other words , don't dismiss this film becau...
# 5      if you can get past the whole comic book thing...
# 6      getting the hughes brothers to direct this see...
# 7      the ghetto in question is , of course , whitec...
# 8      it's a filthy , sooty place where the whores (...
# 9      when the first stiff turns up , copper peter g...
# 10     abberline , a widower , has prophetic dreams h...
# 11     upon arriving in whitechapel , he befriends an...
# 12     i don't think anyone needs to be briefed on ja...
# 13     in the comic , they don't bother cloaking the ...
# 14     it's funny to watch the locals blindly point t...
# 15     and from hell's ending had me whistling the st...
# 16     don't worry - it'll all make sense when you se...
# 17     now onto from hell's appearance : it's certain...
# 18     the print i saw wasn't completely finished ( b...
# 19     oscar winner martin childs' ( shakespeare in l...
# 20     even the acting in from hell is solid , with t...
# 21     ians holm ( joe gould's secret ) and richardso...
# 22     i cringed the first time she opened her mouth ...
# 23                    the film , however , is all good .
# 24     2 : 00 - r for strong violence/gore , sexualit...
# 25     every now and then a movie comes along from a ...
# 26     mtv films' _election , a high school comedy st...
# 27     did anybody know this film existed a week befo...
# 28                      the plot is deceptively simple .
# 29     george washington carver high school is having...
#                              ...
# 270    iron monkey ( actually a reissue of a 1993 fil...
# 271    but it is also a piece of the narrative of leg...
# 272    unlike drunken master 2 , which stars jackie c...
# 273    iron monkey succeeds as no kung fu film since ...
# 274    iron monkey is at its heart a hardcore , kung ...
# 275    however , there are brief moments of profoundn...
# 276    in those moments , and in others , iron monkey...
# 277    while in no way the equal of a masterpiece lik...
# 278              aka siunin wong fei-hung tsi titmalau .
# 279    after watching " rat race " last week , i noti...
# 280    saturday night , i attended another sneak prev...
# 281    " rat race " is a great goofy delight , a dand...
# 282    hands down , this is the most fun film of the ...
# 283    the movie begins with zippy retro-style openin...
# 284                               then comes the setup .
# 285    donald sinclair ( john cleese ) , the extremel...
# 286    to that end , he places a half dozen very spec...
# 287    gathering together the lucky token holders , h...
# 288    the competition is simple : each contestant ge...
# 289    there is a transmitter in every key , so that ...
# 290    the race has no rules ? whichever contestant r...
# 291    since it would be wrong to spoil any of the jo...
# 292    decked out in flashy , trashy clothing and spo...
# 293    she finds that grown-up merrill ( lanai chapma...
# 294    thrown together , it becomes clear that both w...
# 295    owen templeton ( cuba gooding jr . ) is curren...
# 296    an nfl referee , he cost gamblers all over the...
# 297    after escaping from a vengeful cab driver , ow...
# 298    mr . pollini ( rowan atkinson ) is a cheerful ...
# 299    he also is narcoleptic and falls asleep at the...
# Name: text, Length: 300, dtype: object

# %%
# remove1 = '[0-9"#$%&\()*+-/:;<=>?@，。?★、…【】《》[\\]^_`{|}~]+'
# # remove1 = "[^a-zA-Z0-9]+"

# for i in range(len(x_train)):
#     x_train[i] = re.sub(remove1," ",x_train[i])
# for i in range(len(x_train)):
#     x_train[i] = re.sub('[,?!]',".",x_train[i])

# %%
sent = []
for i in range(len(x_train)):
    print('-------------------------------review'+ str(i) + '-----------------------------------------')
    negativeResults = 0
    neutralResults = 0
    positiveResults = 0
    
    for k in x_train[i].split("."):
        k = k.lower()
        sentence = k
        result =  json.loads(nlp.annotate(sentence,properties={'annotators': 'sentiment','outputFormat': 'json'}))
        jsonSentiment = (result)
        for s in jsonSentiment["sentences"]:
            print ( " ".join([word["word"] for word in s["tokens"]]) + " => " + str(s["sentimentValue"]) + " = "+ s["sentiment"])
            if(s["sentiment"] == "Negative"):
                negativeResults = negativeResults + 1
            elif(s["sentiment"] == "Neutral"):
                neutralResults = neutralResults + 1
            elif(s["sentiment"] == "Positive"):
                positiveResults = positiveResults + 1
    print(negativeResults)
    print(positiveResults)
    print(neutralResults)
    if negativeResults > positiveResults and negativeResults > neutralResults:
        print('negative')
        sent.append('negative')
    elif positiveResults > negativeResults and positiveResults > neutralResults:
        print('positive')
        sent.append('positive')
    elif neutralResults > negativeResults and neutralResults > positiveResults:
        print('neutral')
        sent.append('neutral')
# Out:
# -------------------------------review0-----------------------------------------
# films adapted from comic books have had plenty of success , whether they 're about superheroes -LRB- batman , superman , spawn -RRB- , or geared toward kids -LRB- casper -RRB- or the arthouse crowd -LRB- ghost world -RRB- , but there 's never really been a comic book like from hell before => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review1-----------------------------------------
# for starters , it was created by alan moore -LRB- and eddie campbell -RRB- , who brought the medium to a whole new level in the mid '80s with a 12-part series called the watchmen => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review2-----------------------------------------
# to say moore and campbell thoroughly researched the subject of jack the ripper would be like saying michael jackson is starting to look a little odd => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review3-----------------------------------------
# the book -LRB- or '' graphic novel , '' if you will -RRB- is over 500 pages long and includes nearly 30 more that consist of nothing but footnotes => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review4-----------------------------------------
# in other words , do n't dismiss this film because of its source => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review5-----------------------------------------
# if you can get past the whole comic book thing , you might find another stumbling block in from hell 's directors , albert and allen hughes => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review6-----------------------------------------
# getting the hughes brothers to direct this seems almost as ludicrous as casting carrot top in , well , anything , but riddle me this : who better to direct a film that 's set in the ghetto and features really violent street crime than the mad geniuses behind menace ii society ? => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review7-----------------------------------------
# the ghetto in question is , of course , whitechapel in 1888 london 's east end => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review8-----------------------------------------
# it 's a filthy , sooty place where the whores -LRB- called '' unfortunates '' -RRB- are starting to get a little nervous about this mysterious psychopath who has been carving through their profession with surgical precision => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review9-----------------------------------------
# when the first stiff turns up , copper peter godley -LRB- robbie coltrane , the world is not enough -RRB- calls in inspector frederick abberline -LRB- johnny depp , blow -RRB- to crack the case => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review10-----------------------------------------
# abberline , a widower , has prophetic dreams he unsuccessfully tries to quell with copious amounts of absinthe and opium => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review11-----------------------------------------
# upon arriving in whitechapel , he befriends an unfortunate named mary kelly -LRB- heather graham , say it is n't so -RRB- and proceeds to investigate the horribly gruesome crimes that even the police surgeon ca n't stomach => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review12-----------------------------------------
# i do n't think anyone needs to be briefed on jack the ripper , so i wo n't go into the particulars here , other than to say moore and campbell have a unique and interesting theory about both the identity of the killer and the reasons he chooses to slay => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review13-----------------------------------------
# in the comic , they do n't bother cloaking the identity of the ripper , but screenwriters terry hayes -LRB- vertical limit -RRB- and rafael yglesias -LRB- les mis ? => 1 = Negative
# rables -RRB- do a good job of keeping him hidden from viewers until the very end => 3 = Positive
# 1
# 1
# 0
# -------------------------------review14-----------------------------------------
# it 's funny to watch the locals blindly point the finger of blame at jews and indians because , after all , an englishman could never be capable of committing such ghastly acts => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review15-----------------------------------------
# and from hell 's ending had me whistling the stonecutters song from the simpsons for days -LRB- '' who holds back the electric car/who made steve guttenberg a star ? '' -RRB- => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review16-----------------------------------------
# do n't worry - it 'll all make sense when you see it => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review17-----------------------------------------
# now onto from hell 's appearance : it 's certainly dark and bleak enough , and it 's surprising to see how much more it looks like a tim burton film than planet of the apes did -LRB- at times , it seems like sleepy hollow 2 -RRB- => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review18-----------------------------------------
# the print i saw was n't completely finished -LRB- both color and music had not been finalized , so no comments about marilyn manson -RRB- , but cinematographer peter deming -LRB- do n't say a word -RRB- ably captures the dreariness of victorian-era london and helped make the flashy killing scenes remind me of the crazy flashbacks in twin peaks , even though the violence in the film pales in comparison to that in the black-and-white comic => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review19-----------------------------------------
# oscar winner martin childs ' -LRB- shakespeare in love -RRB- production design turns the original prague surroundings into one creepy place => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review20-----------------------------------------
# even the acting in from hell is solid , with the dreamy depp turning in a typically strong performance and deftly handling a british accent => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review21-----------------------------------------
# ians holm -LRB- joe gould 's secret -RRB- and richardson -LRB- 102 dalmatians -RRB- log in great supporting roles , but the big surprise here is graham => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review22-----------------------------------------
# i cringed the first time she opened her mouth , imagining her attempt at an irish accent , but it actually was n't half bad => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review23-----------------------------------------
# the film , however , is all good => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review24-----------------------------------------
# 2 : 00 - r for strong violence/gore , sexuality , language and drug content => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review25-----------------------------------------
# every now and then a movie comes along from a suspect studio , with every indication that it will be a stinker , and to everybody 's surprise -LRB- perhaps even the studio -RRB- the film becomes a critical darling => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review26-----------------------------------------
# mtv films ' _ election , a high school comedy starring matthew broderick and reese witherspoon , is a current example => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review27-----------------------------------------
# did anybody know this film existed a week before it opened ? => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review28-----------------------------------------
# the plot is deceptively simple => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review29-----------------------------------------
# george washington carver high school is having student elections => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review30-----------------------------------------
# tracy flick -LRB- reese witherspoon -RRB- is an over-achiever with her hand raised at nearly every question , way , way , high => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review31-----------------------------------------
# mr => 2 = Neutral
# '' m '' -LRB- matthew broderick -RRB- , sick of the megalomaniac student , encourages paul , a popular-but-slow jock to run => 0 = Verynegative
# 0
# 0
# 1
# neutral
# -------------------------------review32-----------------------------------------
# and paul 's nihilistic sister jumps in the race as well , for personal reasons => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review33-----------------------------------------
# the dark side of such sleeper success is that , because expectations were so low going in , the fact that this was quality stuff made the reviews even more enthusiastic than they have any right to be => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review34-----------------------------------------
# you ca n't help going in with the baggage of glowing reviews , which is in contrast to the negative baggage that the reviewers were likely to have => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review35-----------------------------------------
# _ election , a good film , does not live up to its hype => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review36-----------------------------------------
# what makes _ election _ so disappointing is that it contains significant plot details lifted directly from _ rushmore _ , released a few months earlier => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review37-----------------------------------------
# the similarities are staggering : => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review38-----------------------------------------
# tracy flick -LRB- _ election _ -RRB- is the president of an extraordinary number of clubs , and is involved with the school play => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review39-----------------------------------------
# max fischer -LRB- _ rushmore _ -RRB- is the president of an extraordinary number of clubs , and is involved with the school play => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review40-----------------------------------------
# the most significant tension of _ election _ is the potential relationship between a teacher and his student => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review41-----------------------------------------
# the most significant tension of _ rushmore _ is the potential relationship between a teacher and his student => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review42-----------------------------------------
# tracy flick is from a single parent home , which has contributed to her drive => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review43-----------------------------------------
# max fischer is from a single parent home , which has contributed to his drive => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review44-----------------------------------------
# the male bumbling adult in _ election _ -LRB- matthew broderick -RRB- pursues an extramarital affair , gets caught , and his whole life is ruined => 0 = Verynegative
# 0
# 0
# 0
# -------------------------------review45-----------------------------------------
# he even gets a bee sting => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review46-----------------------------------------
# the male bumbling adult in _ rushmore _ -LRB- bill murray -RRB- pursues an extramarital affair , gets caught , and his whole life is ruined => 0 = Verynegative
# 0
# 0
# 0
# -------------------------------review47-----------------------------------------
# he gets several bee stings => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review48-----------------------------------------
# and so on => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review49-----------------------------------------
# what happened ? => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review50-----------------------------------------
# how is it that an individual screenplay -LRB- _ rushmore _ -RRB- and a novel -LRB- _ election _ -RRB- contain so many significant plot points , and yet both films were probably not even aware of each other , made from two different studios , from a genre -LRB- the high school geeks revenge movie -RRB- that had n't been fully formed yet ? => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review51-----------------------------------------
# even so , the strengths of _ election _ rely upon its fantastic performances from broderick , witherspoon , and newcomer jessica campbell , as paul 's anti-social sister , tammy => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review52-----------------------------------------
# broderick here is playing the mr => 2 = Neutral
# rooney role from _ ferris bueller _ , and he seems to be having the most fun he 's had since then => 3 = Positive
# 0
# 1
# 1
# -------------------------------review53-----------------------------------------
# witherspoon is a revelation => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review54-----------------------------------------
# it 's early in the year , it 's a comedy , and teenagers have little clout , but for my money , witherspoon deserves an oscar nomination => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review55-----------------------------------------
# and once campbell 's character gets going , like in her fantastic speech in the gymnasium , then you 're won over => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review56-----------------------------------------
# one thing that 's been bothering me since i 've seen it => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review57-----------------------------------------
# there is an extraordinary amount of sexuality in this film => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review58-----------------------------------------
# i suppose that , coming from mtv films , i should expect no less => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review59-----------------------------------------
# but the film starts off light and airy , like a sitcom => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review60-----------------------------------------
# as the screws tighten , and the tensions mount , alexander payne decides to add elements that , frankly , distract from the story => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review61-----------------------------------------
# it is bad enough that mr => 1 = Negative
# m does n't like tracy 's determination to win at all costs , but did they have to throw in the student/teacher relationship ? => 2 = Neutral
# 1
# 0
# 1
# -------------------------------review62-----------------------------------------
# even so , there 's no logical reason why mr => 1 = Negative
# m has an affair when he does => 2 = Neutral
# 1
# 0
# 1
# -------------------------------review63-----------------------------------------
# there 's a lot to like in _ election _ , but the plot similarities to _ rushmore _ , and the tonal nosedive it takes as it gets explicitly sex-driven , mark this as a disappointment => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review64-----------------------------------------
# you 've got mail works alot better than it deserves to => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review65-----------------------------------------
# in order to make the film a success , all they had to do was cast two extremely popular and attractive stars , have them share the screen for about two hours and then collect the profits => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review66-----------------------------------------
# no real acting was involved and there is not an original or inventive bone in it 's body -LRB- it 's basically a complete re-shoot of the shop around the corner , only adding a few modern twists -RRB- => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review67-----------------------------------------
# essentially , it goes against and defies all concepts of good contemporary filmmaking => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review68-----------------------------------------
# it 's overly sentimental and at times terribly mushy , not to mention very manipulative => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review69-----------------------------------------
# but oh , how enjoyable that manipulation is => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review70-----------------------------------------
# but there must be something other than the casting and manipulation that makes the movie work as well as it does , because i absolutely hated the previous ryan/hanks teaming , sleepless in seattle => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review71-----------------------------------------
# it could n't have been the directing , because both films were helmed by the same woman => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review72-----------------------------------------
# i have n't quite yet figured out what i liked so much about you 've got mail , but then again , is that really important ? => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review73-----------------------------------------
# if you like something so much , why even question it ? => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review74-----------------------------------------
# again , the storyline is as cliched as they come => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review75-----------------------------------------
# tom hanks plays joe fox , the insanely likeable owner of a discount book chain and meg ryan plays kathleen kelley , the even more insanely likeable proprietor of a family-run children 's book shop called , in a nice homage , the shop around the corner => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review76-----------------------------------------
# fox and kelley soon become bitter rivals because the new fox books store is opening up right across the block from the small business => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review77-----------------------------------------
# little do they know , they are already in love with each other over the internet , only neither party knows the other person 's true identity => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review78-----------------------------------------
# the rest of the story is n't important because all it does is serve as a mere backdrop for the two stars to share the screen => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review79-----------------------------------------
# sure , there are some mildly interesting subplots , but they all fail in comparison to the utter cuteness of the main relationship => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review80-----------------------------------------
# all of this , of course , leads up to the predictable climax => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review81-----------------------------------------
# but as foreseeable as the ending is , it 's so damn cute and well-done that i doubt any movie in the entire year contains a scene the evokes as much pure joy as this part does => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review82-----------------------------------------
# when ryan discovers the true identity of her online love , i was filled with such , for lack of a better word , happiness that for the first time all year , i actually left the theater smiling => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review83-----------------------------------------
# '' jaws '' is a rare film that grabs your attention before it shows you a single image on screen => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review84-----------------------------------------
# the movie opens with blackness , and only distant , alien-like underwater sounds => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review85-----------------------------------------
# then it comes , the first ominous bars of composer john williams ' now infamous score => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review86-----------------------------------------
# dah-dum => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review87-----------------------------------------
# from there , director steven spielberg wastes no time , taking us into the water on a midnight swim with a beautiful girl that turns deadly => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review88-----------------------------------------
# right away he lets us know how vulnerable we all are floating in the ocean , and once '' jaws '' has attacked , it never relinquishes its grip => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review89-----------------------------------------
# perhaps what is most outstanding about '' jaws '' is how spielberg builds the movie => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review90-----------------------------------------
# he works it like a theatrical production , with a first act and a second act => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review91-----------------------------------------
# unlike so many modern filmmakers , he has a great deal of restraint , and refuses to show us the shark until the middle of the second act => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review92-----------------------------------------
# until then , he merely suggests its presence with creepy , subjective underwater shots and williams ' music => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review93-----------------------------------------
# he 's building the tension bit by bit , so when it comes time for the climax , the shark 's arrival is truly terrifying => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review94-----------------------------------------
# he does n't let us get bored with the imagery => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review95-----------------------------------------
# the first act opens with police chief martin brody -LRB- roy scheider -RRB- , a new york cop who has taken an easy , peaceful job running the police station on amity island , a fictitious new england resort town where there has n't been a murder or a gun fired in 25 years => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review96-----------------------------------------
# the island is shaken up by several vicious great white shark attacks right before the fourth of july , and the mayor , larry vaughn -LRB- murray hamilton -RRB- , does n't want to shut down the beaches because the island is reliant on summer tourist money => 0 = Verynegative
# 0
# 0
# 0
# -------------------------------review97-----------------------------------------
# brody is joined by matt hooper -LRB- richard dreyfuss -RRB- , a young , ambitious shark expert from the marine institute => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review98-----------------------------------------
# hooper is as fascinated by the shark as he is determined to help brody stop it -- his knowledge about the exact workings of the shark -LRB- '' it 's a perfect engine , an eating machine '' -RRB- make it that much more terrifying => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review99-----------------------------------------
# when vaughn finally relents , hooper and brody join a crusty old shark killer named quint -LRB- robert shaw -RRB- on his decrepit boat , the orca , to search for the shark => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review100-----------------------------------------
# the entire second act takes place on the orca as the three men hunt the shark , and inevitably , are hunted by it => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review101-----------------------------------------
# '' jaws '' is a thriller with a keen sense of humor and an incredible sense of pacing , tension , and horror => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review102-----------------------------------------
# it is like ten movies all rolled into one , and it 's no wonder it took america by storm in the summer of 1975 , taking in enough money to crown it the box office champ of all time -LRB- until it was unceremoniously dethroned in 1977 by '' star wars '' -RRB- => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review103-----------------------------------------
# even today , fascination with this film is on par with hitchcock 's '' psycho , '' and it never seems to age => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review104-----------------------------------------
# although grand new technology exists that makes the technical sequences , including several mechanical sharks , obsolete , none of it could improve the film because it only would lead to overkill => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review105-----------------------------------------
# the technical limitations faced by spielberg in 1975 may have actually produced a better film because it forced him to rely on traditional cinematic elements like pacing , characterization , sharp editing , and creative photography , instead of simply dousing the audience with digital shark effects => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review106-----------------------------------------
# scheider , dreyfuss , and shaw were known actors at the time '' jaws '' was made , but none of them had the draw of a robert redford or paul newman => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review107-----------------------------------------
# nevertheless , this film guaranteed them all successful careers because each gave an outstanding performance and refused to be overshadowed by the shark => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review108-----------------------------------------
# scheider hits just the right notes as a sympathetic husband and father caught in the political quagmire of doing what 's right and going against the entire town => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review109-----------------------------------------
# '' it 's your first summer here , you know , '' mayor vaughn warns him => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review110-----------------------------------------
# dreyfuss , who had previously been seen in '' american graffiti '' -LRB- 1973 -RRB- and '' the apprenticeship of duddy kravitz '' -LRB- 1974 -RRB- gives a surprisingly mature , complex performance for someone who had literally only played kids and teenagers => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review111-----------------------------------------
# however , most outstanding is the gnarled performance by robert shaw as the movie 's captain ahab , a performance sorely overlooked by the academy awards => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review112-----------------------------------------
# bordering of parody , shaw plays quint as a grizzled old loner whose machismo borders on masochism => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review113-----------------------------------------
# he 's slightly deranged , and shaw 's performance is almost a caricature => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review114-----------------------------------------
# however , there is one scene late in the film , when he and brody and hooper are below deck on the orca comparing scars => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review115-----------------------------------------
# quint is drawn into telling the story of his experiences aboard the u => 3 = Positive
# s => 2 = Neutral
# s => 2 = Neutral
# 0
# 1
# 2
# neutral
# -------------------------------review116-----------------------------------------
# indianapolis , a navy ship in world war ii that was sunk by the japanese => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review117-----------------------------------------
# his tale of floating in the water for more than a week with over 1 , 000 other men while swarms of sharks slowly devoured them them is actually more hair-raising than anything spielberg put on screen => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review118-----------------------------------------
# shaw delivers the story in one long take , and it is the best acting in the film => 4 = Verypositive
# 0
# 0
# 0
# -------------------------------review119-----------------------------------------
# of course , we ca n't leave out the shark itself ; with its black eyes , endless rows of teeth , and insatiable urge to eat , it is basically the epitome of all mankind 's fears about what is unknown and threatening in nature => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review120-----------------------------------------
# a shark is such a perfect nemesis it is real -- having survived sinch the dinosaurs , great whites do exist , they can be as large as the shark in '' jaws , '' and they are a threat => 4 = Verypositive
# 0
# 0
# 0
# -------------------------------review121-----------------------------------------
# every one of spielberg 's subjective underwater shots makes us feel queasy because lets us see how we look to the shark : a bunch of writihing , dangling , completely unprotected legs just ready to be chomped into => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review122-----------------------------------------
# the shark in '' jaws '' was actually a combination of actual footage and five different mechanical sharks -LRB- all nicknamed '' bruce '' by the crew -RRB- built to be shot from different angles => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review123-----------------------------------------
# many have forgotten , but '' jaws '' was a sort of precursor to '' waterworld '' -LRB- 1995 -RRB- , a movie 's who soggy production and cost overruns had universal studios worried about a bomb => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review124-----------------------------------------
# but , as we can see now , spielberg overcame all the obstacles , and delivered one of the finest primal scare-thrillers ever to come out of hollywood => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review125-----------------------------------------
# moviemaking is a lot like being the general manager of an nfl team in the post-salary cap era -- you 've got to know how to allocate your resources => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review126-----------------------------------------
# every dollar spent on a free-agent defensive tackle is one less dollar than you can spend on linebackers or safeties or centers => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review127-----------------------------------------
# in the nfl , this leads to teams like the detroit lions , who boast a superstar running back with a huge contract , but can only field five guys named herb to block for him => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review128-----------------------------------------
# in the movies , you end up with films like '' spawn '' , with a huge special-effects budget but not enough money to hire any recognizable actors => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review129-----------------------------------------
# jackie chan is the barry sanders of moviemaking => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review130-----------------------------------------
# he spins and darts across the screen like sanders cutting back through the defensive line => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review131-----------------------------------------
# watching jackie in operation condor as he drives his motorcycle through the crowded streets of madrid , fleeing an armada of pursuers in identical black compact cars , is reminiscent of sanders running for daylight with the chicago bears in hot pursuit , except that sanders does n't have to worry about rescuing runaway baby carriages => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review132-----------------------------------------
# but like the lions star , jackie does n't have anybody to block for him => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review133-----------------------------------------
# almost every cent that 's invested in a jackie chan movie goes for stunts , and as chan does his own stunts , the rest of the money goes to pay his hospital bills => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review134-----------------------------------------
# this leaves about 75 cents to pay for things like directors -LRB- chan directs -RRB- , scripts and dubbing and supporting characters , not to mention the hideous title sequence => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review135-----------------------------------------
# this also explains why the movie was shot in odd places like morocco and spain => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review136-----------------------------------------
# -LRB- chan 's first release in this country , '' rumble in the bronx '' , was supposedly set in new york , but was filmed in vancouver , and in the chase scenes the canadian rockies are clearly visible => 1 = Negative
# -RRB- => 2 = Neutral
# 1
# 0
# 1
# -------------------------------review137-----------------------------------------
# heck , jackie does n't even have enough money for a haircut , looks like , much less a personal hairstylist => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review138-----------------------------------------
# in condor , chan plays the same character he 's always played , himself , a mixture of bruce lee and tim allen , a master of both kung-fu and slapstick-fu => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review139-----------------------------------------
# jackie is sent by the un to retrieve a cache of lost nazi gold in the north african desert , and is chased by a horde of neo-nazi sympathizers and two stereotypical arabs -LRB- one of the things i like about jackie chan movies : no political correctness -RRB- => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review140-----------------------------------------
# he is joined by three women , who have little to do except scream , '' jackie , save us ! '' => 1 = Negative
# , and misuse firearms => 2 = Neutral
# 1
# 0
# 1
# -------------------------------review141-----------------------------------------
# the villain is an old nazi whose legs were broken in the secret base so that he has to be carried everywhere , and he 's more pathetic than evil => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review142-----------------------------------------
# en route , we have an extended motorcycle chase scene , a hilarious fight in the moroccan version of motel 6 with the neo-nazis , and two confrontations with savage natives => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review143-----------------------------------------
# once at the secret desert base , there is a long chop-socky sequence , followed by the film 's centerpiece , a wind-tunnel fight that 's even better than the one in face/off => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review144-----------------------------------------
# this is where the money was spent , on well-choreographed kung-fu sequences , on giant kevlar hamster balls , on smashed-up crates of bananas , and on scorpions => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review145-----------------------------------------
# ignore the gaping holes in the plot -LRB- how , exactly , if the villain 's legs were broken , did he escape from the secret nazi base , and why did n't he take the key with him ? -RRB- => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review146-----------------------------------------
# do n't worry about the production values , or what , exactly , the japanese girl was doing hitchhiking across the sahara => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review147-----------------------------------------
# just go see the movie => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review148-----------------------------------------
# operation condor has pretentions of being a '' raiders of the lost ark '' knockoff , but one wonders what jackie could do with the raiders franchise blocking for him -- with a lawrence kazdan screenplay , a john williams score , spielberg directing and george lucas producing , condor might be an a + movie => 0 = Verynegative
# 0
# 0
# 0
# -------------------------------review149-----------------------------------------
# however , you 've got to go with what you 've got , and what you 've got in jackie chan is something special -- a talent that mainstream hollywood should , could , and ought to utilize => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review150-----------------------------------------
# on june 30 , 1960 , a self-taught , idealistic , yet pragmatic , young man became , at age 36 , the first head of government of a newly independent african state , formerly the belgian congo => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review151-----------------------------------------
# two months later , he was ousted from his powerful position and hunted by government troops until he was captured and brutally murdered along with two aides => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review152-----------------------------------------
# this little-known story of this meteoric rise and fall is told my international filmmaker raoul peck in '' lumumba => 1 = Negative
# '' => 2 = Neutral
# 1
# 0
# 1
# -------------------------------review153-----------------------------------------
# patrice lumumba 's -LRB- eriq ebouaney -RRB- story has been told previously by helmer peck in his 1991 award winning documentary , '' lumumba - death of a prophet , '' virtually guaranteeing that his new , fictional account of a patriot remains true to its subject => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review154-----------------------------------------
# peck , with co-writer pascal bonitzer , begins at the end of the story of the young political leader => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review155-----------------------------------------
# we watch as two white men perform the gruesome task of dismembering the bodies of three black men => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review156-----------------------------------------
# images of hatchets , saws and fast-emptying whiskey bottles accompany the grisly image => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review157-----------------------------------------
# jump back a few years to a meeting among the black leaders in the belgian-owned congo => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review158-----------------------------------------
# a third class postal worker , lumumba , speaks his mind to heads of the most powerful tribes , proclaiming himself not tribal , not regional , but a national leader => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review159-----------------------------------------
# his small , mobile party , the congolese national movement -LRB- mnc -RRB- is gaining prominence and patrice leaves his clerical job to sell beer , and get his face known , in the bustling capital , stanleyville => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review160-----------------------------------------
# at a time when the colonial empires are falling down around the world , lumumba is in the right place at the right time and , through political savvy and chess-like manipulation , achieves a position of leadership of the mnc => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review161-----------------------------------------
# as the date for independence approaches , he tactically positions himself to be the new nation 's first prime minister and defense minister , supporting the presidency of joseph kasa vubu -LRB- maka kotto -RRB- => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review162-----------------------------------------
# the coalition he created soon starts to fall apart as the former belgian masters continue to exert influence on the struggling nation as they strive to maintain economic hold on the country 's vast natural resources of copper , diamonds , gold and more => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review163-----------------------------------------
# lumumba wo n't seek the help of the us , knowing that they would try to create de facto american control of the fledgling government => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review164-----------------------------------------
# his initial investigation into soviet assistance immediately tags patrice as a communist and his integrity is overshadowed by the cold war threat of russian domination => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review165-----------------------------------------
# the situation goes from bad to worse as the army mutinies , the remaining whites begin to evacuate or arm themselves , belgian troops violently intervene , the lucrative katanga province succeeds under the leadership of rival moise tschombe -LRB- pascal nzonzi -RRB- and lumumba is refused access to his own country when he returns from a conference abroad => 0 = Verynegative
# 0
# 0
# 0
# -------------------------------review166-----------------------------------------
# this tumultuous and little known period of modern african history saw a score of nations struggling for independence from the sometimes-odious colonialists who have ruled much of the world from their european seats of power for centuries => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review167-----------------------------------------
# peck focuses his story on familiar material that strives to give an honest portrayal of patrice lumumba , his friend and foes and the independence movements that gripped africa in the 50 's and 60 's => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review168-----------------------------------------
# -LRB- during the time the story takes place , many new nations , including nigeria and somalia , were born , with varying degrees of success and failure , usually dependent upon which country colonized them => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review169-----------------------------------------
# some colonial masters were better than others => 1 = Negative
# -RRB- => 2 = Neutral
# 1
# 0
# 1
# -------------------------------review170-----------------------------------------
# the effort involved in '' lumumba '' is quite ambitious as peck and his crew before and behind the camera strive to bring to life this slice of world history that might have gone unexplored for decades , if at all => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review171-----------------------------------------
# production values are first rate on what must be a small , by us standards , budget => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review172-----------------------------------------
# the period feel and realistic african settings are nicely maintained in a production that traveled from zimbabwe to mozambique => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review173-----------------------------------------
# the screenplay covers a lot of ground and does yeoman 's work in providing a great deal of detailed history while trying to do justice to the story of lumumba 's life => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review174-----------------------------------------
# the political side of things is evenly told in a linear , straightforward manner that teaches , not preaches => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review175-----------------------------------------
# it concentrates on the good deeds of the man , if a bit as a stalwart saint , but does n't embellish on a larger than life persona => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review176-----------------------------------------
# the family side of patrice 's life is handled in several , perfunctory and brief interludes that show him talking to one of his children , embracing his wife or lamenting the death of his child => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review177-----------------------------------------
# i know the intent is to flesh the man out , but too short a shrift is given to the family man side of lumumba => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review178-----------------------------------------
# the story , as such , has a lopsided feel about it => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review179-----------------------------------------
# high marks go to eriq ebouaney as the title character => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review180-----------------------------------------
# the actor gives a convincing , charismatic performance as the multifaceted , politically deft patrice lumumba who has the good of his people and his country as the force driving his own ambitions => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review181-----------------------------------------
# in true docudrama tradition , the supporting cast does not outshine the star , complementing his good efforts , instead => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review182-----------------------------------------
# '' lumumba '' is a solid , interesting , educational and honest docudrama that should appeal to film buffs and politicos , both => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review183-----------------------------------------
# it has more intelligence in its telling than anything i 've seen out of hollywood for months and i give it a b + => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review184-----------------------------------------
# apparently , director tony kaye had a major battle with new line regarding his new film , american history x => 1 = Negative
# i do n't know the details of the fight , but it seems that he is not happy with the final product , and nearly removed his name from the credits altogether => 1 = Negative
# 2
# 0
# 0
# negative
# -------------------------------review185-----------------------------------------
# i 've heard about this kind of thing happening before , and it makes me wonder how much input a studio has over the films they produce => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review186-----------------------------------------
# as it is , i found american history x to be an extremely good film , not just because of tony kaye 's focused look at the touchy subject of racism , but because of a powerful , charismatic performance from edward norton => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review187-----------------------------------------
# ...
# 0
# 0
# 0
# -------------------------------review234-----------------------------------------
# sheedy expresses more with just her eyes than ringwald does with her entire body => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review235-----------------------------------------
# it 's anthony lapaglia , however , who seizes the spotlight => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review236-----------------------------------------
# lapaglia plays stevie dee , a suave , overly polite mafioso who is formally courting sheedy with old-fashioned chivalry => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review237-----------------------------------------
# lapaglia 's sincere but dim-witted character is a riot => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review238-----------------------------------------
# and what 's uncanny is that lapaglia is a dead ringer for robert de niro , with a little bit of alec baldwin thrown in for good measure => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review239-----------------------------------------
# lapaglia seems to have attended the de niro school of gangster acting , and his inspired performance is partly a tribute to his role-model and partly a rip-off => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review240-----------------------------------------
# i do n't know whether to say a star is born or a star is re-born , but i do know that lapaglia 's over-the-top performance should not be missed => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review241-----------------------------------------
# the scrumptious comic acting , however , extends well beyond sheedy and lapaglia => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review242-----------------------------------------
# joe pesci , in particular , sinks his teeth into his role as alda 's unscrupulous brother-in-law , a slum lord with mob ties , who is cheating on his wife -LRB- catherine o'hara -RRB- => 0 = Verynegative
# 0
# 0
# 0
# -------------------------------review243-----------------------------------------
# alda , faced with challenge of both directing and acting , somehow finds just the right comic touch as the bride 's financially-strapped father , a carpenter whose dreams are bigger than his wallet => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review244-----------------------------------------
# the film adopts alda 's psychological point of view as he tries to one : plan the wedding , and two : pay for it => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review245-----------------------------------------
# as a filmmaker , alda 's style of humor is remarkably restrained and tasteful => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review246-----------------------------------------
# and while he does n't have the comic genius of a woody allen , alda does possess the inspiration to make movies which are ten times more entertaining than the slop which usually passes for comedy => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review247-----------------------------------------
# after bloody clashes and independence won , lumumba refused to pander to the belgians , who continued a condescending and paternalistic relationship with the congo => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review248-----------------------------------------
# their officers , particularly general janssens -LRB- rudi delhem -RRB- in the force publique , the congo 's army , caused rebellions , undermining lumumba , who was outraged at the rape and murder of belgian nationals => 0 = Verynegative
# 0
# 0
# 0
# -------------------------------review249-----------------------------------------
# with unrest building , moise tshombe -LRB- pascal nzonzi -RRB- and the province of katanga , which contained 70 percent of the country 's resources , proclaimed secession => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review250-----------------------------------------
# lumumba replaced janssens , making mobutu a colonel , and went on a pacification => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review251-----------------------------------------
# tour with congolese president joseph kasa vubu -LRB- maka kotto -RRB- , but it was too late => 0 = Verynegative
# 0
# 0
# 0
# -------------------------------review252-----------------------------------------
# ` when you want to drown a dog , you say it has rabies , ' prophesies lumumba of his own fate => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review253-----------------------------------------
# peck and bonitzer do an exemplary job telling a complicated tale with a myriad of players , although they frequently succumb to cliche , particularly regarding lumumba 's private life => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review254-----------------------------------------
# peck 's script illuminates bantu sayings like ` the hand that gives , rules ' when lumumba uses it with the american ambassador => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review255-----------------------------------------
# peck 's direction is less assured , with many scenes unfortunately playing like standard television fare => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review256-----------------------------------------
# he 's served well , though , by his casting of ebouaney in the title role => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review257-----------------------------------------
# ebouaney is dynamic , radiating his character 's fierce passion for his people and his country => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review258-----------------------------------------
# lumumba 's intelligence and ability to strategize , even as he 's cornered by insurmountable odds , are given life by ebouaney => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review259-----------------------------------------
# peck 's subject and lead actor elevate his film above its mediocre production => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review260-----------------------------------------
# '' lumumba '' is a story that deserves to be told and ebouaney 's performance makes the tragedy personally felt => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review261-----------------------------------------
# the american action film has been slowly drowning to death in a sea of asian wire-fu copycats => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review262-----------------------------------------
# it 's not a pretty death , and it 's leaving the likes of schwartznager , stallone , and van damme wearing cement galoshes at the bottom of a kung fu sea => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review263-----------------------------------------
# sometimes , the mix results in a mind-blowing spectacle unlike any other => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review264-----------------------------------------
# quality action with amazing and exciting stunt work , as in 1999 's the matrix , can be a real gem => 4 = Verypositive
# 0
# 0
# 0
# -------------------------------review265-----------------------------------------
# but too often hollywood gets it wrong , even when they pay off chinese directors => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review266-----------------------------------------
# flying ninjas and floating karate masters have been replaced by soaring bronx detectives and slow motion kicking scientists => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review267-----------------------------------------
# mostly it 's laughable => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review268-----------------------------------------
# in hollywood 's rush to emulate the success of the matrix , trademark asian stunt choreography has become more of a joke than an art form => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review269-----------------------------------------
# but iron monkey , the latest asian import , shows us how to get it right => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review270-----------------------------------------
# iron monkey -LRB- actually a reissue of a 1993 film -RRB- is the story of a 19th chinese vigilante -LRB- rongguang yu -RRB- , fighting with his own unique style of shaolin kung fu for the rights of the oppressed and the bellies of the hungry => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review271-----------------------------------------
# but it is also a piece of the narrative of legendary chinese film hero wong fei-hong , most recently seen in one of the most overlooked , and possibly best films of 2000 , drunken master 2 -LRB- released in the u => 3 = Positive
# s => 2 = Neutral
# as the legend of drunken master -RRB- => 2 = Neutral
# 0
# 1
# 2
# neutral
# -------------------------------review272-----------------------------------------
# unlike drunken master 2 , which stars jackie chan as an adult fei-hong , iron monkey finds a much younger fei-hong -LRB- sze-man tsang -RRB- and his father wong kei-ying -LRB- yen chi dan -RRB- thrust into the middle of iron monkey 's fight against oppression => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review273-----------------------------------------
# iron monkey succeeds as no kung fu film since drunken master 2 => 1 = Negative
# at times , fighting styles , especially that of monkey himself , do devolve into the ridiculous twinkle-toed floating of films like crouching tiger , hidden dragon , director yuen wo ping eventually remembers to bring his action scenes back to earth => 1 = Negative
# 2
# 0
# 0
# negative
# -------------------------------review274-----------------------------------------
# iron monkey is at its heart a hardcore , kung fu action film rather than any kind of drama a la crouching tiger => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review275-----------------------------------------
# however , there are brief moments of profoundness shared between characters , such as those that pass between our outlaw hero and his good-hearted but misguided enemy , chief fox => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review276-----------------------------------------
# in those moments , and in others , iron monkey manages to transcend its mindless kung fu nature to touch the hearts and minds of its audience => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review277-----------------------------------------
# while in no way the equal of a masterpiece like drunken master 2 , iron monkey dances quite nicely to the invading kung fu tune => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review278-----------------------------------------
# aka siunin wong fei-hung tsi titmalau => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review279-----------------------------------------
# after watching '' rat race '' last week , i noticed my cheeks were sore and realized that , when not laughing aloud , i had held a grin for virtually all of the film 's 112 minutes => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review280-----------------------------------------
# saturday night , i attended another sneak preview for the movie and damned if i did n't enjoy it as much the second time as the first => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review281-----------------------------------------
# '' rat race '' is a great goofy delight , a dandy mix of energetic performances , inspired sight gags and flat-out silliness => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review282-----------------------------------------
# hands down , this is the most fun film of the summer => 4 = Verypositive
# 0
# 0
# 0
# -------------------------------review283-----------------------------------------
# the movie begins with zippy retro-style opening credits that look like they were torn straight out of a '60s slapstick comedy , featuring animated photos of the cast attached to herky-jerky bodies bounding around the screen => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review284-----------------------------------------
# then comes the setup => 2 = Neutral
# 0
# 0
# 1
# neutral
# -------------------------------review285-----------------------------------------
# donald sinclair -LRB- john cleese -RRB- , the extremely rich owner of the venetian hotel and casino in las vegas , enjoys concocting unusual bets for his high rolling clients => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review286-----------------------------------------
# to that end , he places a half dozen very special tokens in his slot machines => 3 = Positive
# 0
# 1
# 0
# positive
# -------------------------------review287-----------------------------------------
# gathering together the lucky token holders , he explains , '' today you have a chance to play a game where the odds of winning are one in six => 3 = Positive
# '' => 2 = Neutral
# 0
# 1
# 1
# -------------------------------review288-----------------------------------------
# the competition is simple : each contestant gets a key that opens a locker in silver city , n => 3 = Positive
# m => 2 = Neutral
# , containing $ 2 million in cash => 2 = Neutral
# 0
# 1
# 2
# neutral
# -------------------------------review289-----------------------------------------
# there is a transmitter in every key , so that sinclair and his cronies can keep track of who is ahead => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review290-----------------------------------------
# the race has no rules ? => 2 = Neutral
# whichever contestant reaches the locker first gets the money => 1 = Negative
# 1
# 0
# 1
# -------------------------------review291-----------------------------------------
# since it would be wrong to spoil any of the jokes , let 's use the next few paragraphs to profile the racers => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review292-----------------------------------------
# decked out in flashy , trashy clothing and sporting big hair , vera baker -LRB- whoopi goldberg -RRB- is in town to reunite with the daughter she gave up for adoption as a baby => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review293-----------------------------------------
# she finds that grown-up merrill -LRB- lanai chapman -RRB- is erudite , conservative and more than a little bit wary of this stranger trying to jump into her life => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review294-----------------------------------------
# thrown together , it becomes clear that both women share a fierce competitive nature => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review295-----------------------------------------
# owen templeton -LRB- cuba gooding jr => 1 = Negative
# -RRB- is currently the most hated man in america => 1 = Negative
# 2
# 0
# 0
# negative
# -------------------------------review296-----------------------------------------
# an nfl referee , he cost gamblers all over the country enormous amounts of money by blowing a call in a high-profile game => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review297-----------------------------------------
# after escaping from a vengeful cab driver , owen gets to new mexico by masquerading as the driver for a busload of lucy ricardo impersonators heading to a convention => 1 = Negative
# 1
# 0
# 0
# negative
# -------------------------------review298-----------------------------------------
# mr => 2 = Neutral
# pollini -LRB- rowan atkinson -RRB- is a cheerful , odd little italian man on holiday in america => 1 = Negative
# 1
# 0
# 1
# -------------------------------review299-----------------------------------------
# he also is narcoleptic and falls asleep at the most inopportune times => 1 = Negative
# 1
# 0
# 0
# negative
